# %%
import pandas as pd

# %%
data=pd.read_csv('footfall.csv')

# %%
data.isna().sum()
# Out:
# Month-Year    0
# Footfalls     0
# dtype: int64

# %%
data.describe()
# Out:
#          Footfalls
# count   153.000000
# mean   1814.339869
# std     178.620598
# min    1361.000000
# 25%    1693.000000
# 50%    1824.000000
# 75%    1956.000000
# max    2223.000000

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
stats.probplot(data['Footfalls'], dist="norm", plot=plt)
plt.title("QQ Plot")
plt.savefig('sample_plot.png')
plt.show()
